# %% [markdown]
# <a href="https://colab.research.google.com/github/ALGO3AE2025/ALGORITMO/blob/main/Bem_vindo_ao_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p><img alt="Colaboratory logo" height="45px" src="https://colab.research.google.com/img/colab_favicon.ico" align="left" hspace="10px" vspace="0px"></p>
#
# ## Bem-vindo ao colaborativo! **
#
# O Collaboratory é um ambiente de notebook gratuito da Jupyter que não requer configuração e é executado inteiramente na nuvem.
#
# Com o Collaboratory você pode escrever e executar código, salvar e compartilhar suas análises e acessar poderosos recursos de computação, tudo gratuitamente no seu navegador. Para ver a tradução do vídeo click na opção "Habilitar legenda, Detalhes > Legenda(CC) > Traduzir automaticamente > Portugues ".

# %% [markdown]
# ALGO3AE2025 ATUALIZAÇÃO - ORIGEM

# %%
import random
import math

class ArtefatoAlienigena:
    def __init__(self, origem="desconhecida", **kwargs):
        self.origem = origem
        self.atributos = {atributo: kwargs.get(atributo, 5) for atributo in [
            "material", "estrutura", "interacao_termica", "tecnologia", "impacto_ambiental",
            "comportamento_eletromagnetico", "analise_biologica", "analise_quimica", "origem_espacial",
            "comunicacao", "interacao_gravitacional", "mudanca_estado", "autonomia",
            "similaridade_tecnologica", "singularidade", "capacidade_adaptativa", "movimento_continuo",
            "identificacao_padroes_ocultos", "sincronizacao_espectral_avancada",
            "alinhamento_dinamico_corpos_celestes", "autonomia_reativa", "sensibilidade_manuseio",
            "emissao_radiacao", "resistencia_interferencia", "alteracao_massa",
            "registro_atividade_historica", "furtividade", "reflexao_energia", "analise_temporal",
            "anomalia_simetrica", "microestruturas_desconhecidas", "reatividade_estimulos_opticos",
            "armazenamento_dados", "correlacao_padroes_matematicos", "interacao_baixa_frequencia",
            "replicacao_estrutural", "alteracao_peso_ambientes_controlados",
            "presenca_compostos_organicos", "registro_arqueologico", "resposta_variacoes_magneticas",
            "padroes_desgaste_anormais", "variacao_termica_interna", "uso_marcador_localizacao",
            "interacao_liquidos_condutores", "comportamento_microgravidade", "modulacao_sonora",
            "influencia_campo_eletrico", "interacao_redes_comunicacao", "registro_eventos_luminosos",
            "estruturas_ocultas_escaneamento", "absorcao_ondas_radio", "analise_radiacao_residual",
            "comparacao_tecnologia_avancada", "efeito_fauna_local", "distribuicao_massa_interna",
            "correlacao_simbolos_antigos", "funcao_objeto_ritualistico", "reversao_estados_fisicos",
            "ativacao_por_contato_humano", "correlacao_artefatos_extraterrestres"
        ]}

        self.pesos = {
            "tecnologia": 20, "autonomia_reativa": 18, "emissao_radiacao": 19, "furtividade": 18,
            "impacto_ambiental": 16, "alteracao_massa": 15, "registro_atividade_historica": 14,
            "origem_espacial": 13, "comunicacao": 12, "resistencia_interferencia": 11,
            "modulacao_sonora": 10, "interacao_redes_comunicacao": 9
        }

        self.historico_analises = []

    def calcular_ameaca(self):
        score = sum(self.atributos.get(fator, 5) * self.pesos.get(fator, 10) for fator in self.atributos)
        score = (score / (15 * sum(self.pesos.values()))) * 100
        score = min(score, 82.44)

        resultado = f"⚠️ **PROBABILIDADE DE AMEAÇA: {score:.2f}%** ⚠️ - **ORIGEM: {self.origem.upper()}**"
        self.historico_analises.append(resultado)
        return resultado

# Criando artefatos com origem definida
artefato_terra = ArtefatoAlienigena(origem="morador", tecnologia=15, autonomia_reativa=15, emissao_radiacao=15)
artefato_espacial = ArtefatoAlienigena(origem="visitante", tecnologia=14, autonomia_reativa=14, emissao_radiacao=14)

# Executando análises
print(artefato_terra.calcular_ameaca())
print(artefato_espacial.calcular_ameaca())
# Out:
# ⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️ - **ORIGEM: MORADOR**
# ⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️ - **ORIGEM: VISITANTE**

# %%
import random
import math

class ArtefatoAlienigena:
    def __init__(self, origem="desconhecida", **kwargs):
        self.origem = origem
        self.atributos = {atributo: kwargs.get(atributo, 5) for atributo in [
            "material", "estrutura", "interacao_termica", "tecnologia", "impacto_ambiental",
            "comportamento_eletromagnetico", "analise_biologica", "analise_quimica", "origem_espacial",
            "comunicacao", "interacao_gravitacional", "mudanca_estado", "autonomia",
            "similaridade_tecnologica", "singularidade", "capacidade_adaptativa", "movimento_continuo",
            "identificacao_padroes_ocultos", "sincronizacao_espectral_avancada",
            "alinhamento_dinamico_corpos_celestes", "autonomia_reativa", "sensibilidade_manuseio",
            "emissao_radiacao", "resistencia_interferencia", "alteracao_massa",
            "registro_atividade_historica", "furtividade", "reflexao_energia", "analise_temporal",
            "anomalia_simetrica", "microestruturas_desconhecidas", "reatividade_estimulos_opticos",
            "armazenamento_dados", "correlacao_padroes_matematicos", "interacao_baixa_frequencia",
            "replicacao_estrutural", "alteracao_peso_ambientes_controlados",
            "presenca_compostos_organicos", "registro_arqueologico", "resposta_variacoes_magneticas",
            "padroes_desgaste_anormais", "variacao_termica_interna", "uso_marcador_localizacao",
            "interacao_liquidos_condutores", "comportamento_microgravidade", "modulacao_sonora",
            "influencia_campo_eletrico", "interacao_redes_comunicacao", "registro_eventos_luminosos",
            "estruturas_ocultas_escaneamento", "absorcao_ondas_radio", "analise_radiacao_residual",
            "comparacao_tecnologia_avancada", "efeito_fauna_local", "distribuicao_massa_interna",
            "correlacao_simbolos_antigos", "funcao_objeto_ritualistico", "reversao_estados_fisicos",
            "ativacao_por_contato_humano", "correlacao_artefatos_extraterrestres"
        ]}

        self.pesos = {
            "tecnologia": 20, "autonomia_reativa": 18, "emissao_radiacao": 19, "furtividade": 18,
            "impacto_ambiental": 16, "alteracao_massa": 15, "registro_atividade_historica": 14,
            "origem_espacial": 13, "comunicacao": 12, "resistencia_interferencia": 11,
            "modulacao_sonora": 10, "interacao_redes_comunicacao": 9
        }

        self.historico_analises = []

    def calcular_ameaca(self):
        score = sum(self.atributos.get(fator, 5) * self.pesos.get(fator, 10) for fator in self.atributos)
        score = (score / (15 * sum(self.pesos.values()))) * 100
        score = min(score, 82.44)

        resultado = f"⚠️ **PROBABILIDADE DE AMEAÇA: {score:.2f}%** ⚠️ - **ORIGEM: {self.origem.upper()}**"
        self.historico_analises.append(resultado)
        return resultado

    def exibir_historico(self):
        return self.historico_analises

# Criando artefatos com origem definida
artefato_terra = ArtefatoAlienigena(origem="morador", tecnologia=15, autonomia_reativa=15, emissao_radiacao=15)
artefato_espacial = ArtefatoAlienigena(origem="visitante", tecnologia=14, autonomia_reativa=14, emissao_radiacao=14)

# Executando análises
print(artefato_terra.calcular_ameaca())
print(artefato_espacial.calcular_ameaca())

# Exibindo histórico
print(artefato_terra.exibir_historico())
print(artefato_espacial.exibir_historico())
# Out:
# ⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️ - **ORIGEM: MORADOR**
# ⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️ - **ORIGEM: VISITANTE**
# ['⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️ - **ORIGEM: MORADOR**']
# ['⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️ - **ORIGEM: VISITANTE**']

# %%
import random
import math

class ArtefatoAlienigena:
    def __init__(self, origem="desconhecida", **kwargs):
        self.origem = origem
        self.atributos = {atributo: kwargs.get(atributo, random.randint(5, 15)) for atributo in [
            "material", "estrutura", "interacao_termica", "tecnologia", "impacto_ambiental",
            "comportamento_eletromagnetico", "analise_biologica", "analise_quimica", "origem_espacial",
            "comunicacao", "interacao_gravitacional", "mudanca_estado", "autonomia",
            "similaridade_tecnologica", "singularidade", "capacidade_adaptativa", "movimento_continuo",
            "identificacao_padroes_ocultos", "sincronizacao_espectral_avancada",
            "alinhamento_dinamico_corpos_celestes", "autonomia_reativa", "sensibilidade_manuseio",
            "emissao_radiacao", "resistencia_interferencia", "alteracao_massa",
            "registro_atividade_historica", "furtividade", "reflexao_energia", "analise_temporal",
            "anomalia_simetrica", "microestruturas_desconhecidas", "reatividade_estimulos_opticos",
            "armazenamento_dados", "correlacao_padroes_matematicos", "interacao_baixa_frequencia",
            "replicacao_estrutural", "alteracao_peso_ambientes_controlados",
            "presenca_compostos_organicos", "registro_arqueologico", "resposta_variacoes_magneticas",
            "padroes_desgaste_anormais", "variacao_termica_interna", "uso_marcador_localizacao",
            "interacao_liquidos_condutores", "comportamento_microgravidade", "modulacao_sonora",
            "influencia_campo_eletrico", "interacao_redes_comunicacao", "registro_eventos_luminosos",
            "estruturas_ocultas_escaneamento", "absorcao_ondas_radio", "analise_radiacao_residual",
            "comparacao_tecnologia_avancada", "efeito_fauna_local", "distribuicao_massa_interna",
            "correlacao_simbolos_antigos", "funcao_objeto_ritualistico", "reversao_estados_fisicos",
            "ativacao_por_contato_humano", "correlacao_artefatos_extraterrestres"
        ]}

        self.pesos = {
            "tecnologia": 20, "autonomia_reativa": 18, "emissao_radiacao": 19, "furtividade": 18,
            "impacto_ambiental": 16, "alteracao_massa": 15, "registro_atividade_historica": 14,
            "origem_espacial": 13, "comunicacao": 12, "resistencia_interferencia": 11,
            "modulacao_sonora": 10, "interacao_redes_comunicacao": 9
        }

        self.historico_analises = []

    def calcular_ameaca(self):
        score = sum(self.atributos.get(fator, random.randint(5, 15)) * self.pesos.get(fator, random.randint(5, 20)) for fator in self.pesos)
        score = (score / (15 * sum(self.pesos.values()))) * 100

        # Adicionando variação realista e evitando um único valor fixo
        score = min(max(score, random.uniform(30.0, 90.0)), 99.99)

        resultado = f"⚠️ **PROBABILIDADE DE AMEAÇA: {score:.2f}%** ⚠️ - **ORIGEM: {self.origem.upper()}**"
        self.historico_analises.append(resultado)
        return resultado

    def exibir_historico(self):
        return self.historico_analises

# Criando artefatos com atributos realistas e origem definida
artefato_terra = ArtefatoAlienigena(origem="morador", tecnologia=random.randint(10, 15), autonomia_reativa=random.randint(8, 15))
artefato_espacial = ArtefatoAlienigena(origem="visitante", tecnologia=random.randint(6, 14), autonomia_reativa=random.randint(5, 13))

# Executando análises
print(artefato_terra.calcular_ameaca())
print(artefato_espacial.calcular_ameaca())

# Exibindo histórico
print(artefato_terra.exibir_historico())
print(artefato_espacial.exibir_historico())
# Out:
# ⚠️ **PROBABILIDADE DE AMEAÇA: 89.14%** ⚠️ - **ORIGEM: MORADOR**
# ⚠️ **PROBABILIDADE DE AMEAÇA: 80.22%** ⚠️ - **ORIGEM: VISITANTE**
# ['⚠️ **PROBABILIDADE DE AMEAÇA: 89.14%** ⚠️ - **ORIGEM: MORADOR**']
# ['⚠️ **PROBABILIDADE DE AMEAÇA: 80.22%** ⚠️ - **ORIGEM: VISITANTE**']

# %%
import random
import math

class ArtefatoAlienigena:
    def __init__(self, origem="desconhecida", **kwargs):
        self.origem = origem
        self.atributos = {atributo: kwargs.get(atributo, 5) for atributo in [
            "material", "estrutura", "interacao_termica", "tecnologia", "impacto_ambiental",
            "comportamento_eletromagnetico", "analise_biologica", "analise_quimica", "origem_espacial",
            "comunicacao", "interacao_gravitacional", "mudanca_estado", "autonomia",
            "similaridade_tecnologica", "singularidade", "capacidade_adaptativa", "movimento_continuo",
            "identificacao_padroes_ocultos", "sincronizacao_espectral_avancada",
            "alinhamento_dinamico_corpos_celestes", "autonomia_reativa", "sensibilidade_manuseio",
            "emissao_radiacao", "resistencia_interferencia", "alteracao_massa",
            "registro_atividade_historica", "furtividade", "reflexao_energia", "analise_temporal",
            "anomalia_simetrica", "microestruturas_desconhecidas", "reatividade_estimulos_opticos",
            "armazenamento_dados", "correlacao_padroes_matematicos", "interacao_baixa_frequencia",
            "replicacao_estrutural", "alteracao_peso_ambientes_controlados",
            "presenca_compostos_organicos", "registro_arqueologico", "resposta_variacoes_magneticas",
            "padroes_desgaste_anormais", "variacao_termica_interna", "uso_marcador_localizacao",
            "interacao_liquidos_condutores", "comportamento_microgravidade", "modulacao_sonora",
            "influencia_campo_eletrico", "interacao_redes_comunicacao", "registro_eventos_luminosos",
            "estruturas_ocultas_escaneamento", "absorcao_ondas_radio", "analise_radiacao_residual",
            "comparacao_tecnologia_avancada", "efeito_fauna_local", "distribuicao_massa_interna",
            "correlacao_simbolos_antigos", "funcao_objeto_ritualistico", "reversao_estados_fisicos",
            "ativacao_por_contato_humano", "correlacao_artefatos_extraterrestres"
        ]}

        self.pesos = {
            "tecnologia": 20, "autonomia_reativa": 18, "emissao_radiacao": 19, "furtividade": 18,
            "impacto_ambiental": 16, "alteracao_massa": 15, "registro_atividade_historica": 14,
            "origem_espacial": 13, "comunicacao": 12, "resistencia_interferencia": 11,
            "modulacao_sonora": 10, "interacao_redes_comunicacao": 9
        }

        self.historico_analises = []

    def calcular_ameaca(self):
        score = sum(self.atributos.get(fator, 5) * self.pesos.get(fator, 10) for fator in self.atributos)
        score = (score / (15 * sum(self.pesos.values()))) * 100
        score = min(score, 82.44)

        resultado = f"⚠️ **PROBABILIDADE DE AMEAÇA: {score:.2f}%** ⚠️"
        origem_info = f"🛸 **ORIGEM DO ARTEFATO:** {self.origem.upper()}"

        self.historico_analises.append((resultado, origem_info))
        return resultado, origem_info

    def exibir_historico(self):
        return self.historico_analises

# Criando artefatos com origem definida
artefato_terra = ArtefatoAlienigena(origem="morador", tecnologia=15, autonomia_reativa=15, emissao_radiacao=15)
artefato_espacial = ArtefatoAlienigena(origem="visitante", tecnologia=14, autonomia_reativa=14, emissao_radiacao=14)

# Executando análises
resultado_terra, origem_terra = artefato_terra.calcular_ameaca()
resultado_espacial, origem_espacial = artefato_espacial.calcular_ameaca()

print(resultado_terra)
print(origem_terra)

print(resultado_espacial)
print(origem_espacial)

# Exibindo histórico
print(artefato_terra.exibir_historico())
print(artefato_espacial.exibir_historico())
# Out:
# ⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️
# 🛸 **ORIGEM DO ARTEFATO:** MORADOR
# ⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️
# 🛸 **ORIGEM DO ARTEFATO:** VISITANTE
# [('⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️', '🛸 **ORIGEM DO ARTEFATO:** MORADOR')]
# [('⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️', '🛸 **ORIGEM DO ARTEFATO:** VISITANTE')]

# %%
import random
import math

class ArtefatoAlienigena:
    def __init__(self, **kwargs):
        self.atributos = {atributo: kwargs.get(atributo, 5) for atributo in [
            "registro_arqueologico", "impacto_ambiental", "analise_quimica", "analise_biologica",
            "origem_espacial", "comunicacao", "tecnologia", "autonomia_reativa", "emissao_radiacao"
        ]}

        self.pesos = {
            "registro_arqueologico": 15, "impacto_ambiental": 14, "analise_quimica": 13,
            "analise_biologica": 12, "origem_espacial": 20, "tecnologia": 18, "autonomia_reativa": 16,
            "emissao_radiacao": 19
        }

        self.origem = self.definir_origem()

        self.historico_analises = []

    def definir_origem(self):
        # Se registro arqueológico, impacto ambiental, química e biologia forem altos, é Morador
        if (self.atributos["registro_arqueologico"] >= 10 and
            self.atributos["impacto_ambiental"] >= 10 and
            self.atributos["analise_quimica"] >= 10 and
            self.atributos["analise_biologica"] >= 10):
            return "Morador"
        else:
            return "Visitante"

    def calcular_ameaca(self):
        score = sum(self.atributos.get(fator, 5) * self.pesos.get(fator, 10) for fator in self.atributos)
        score = (score / (15 * sum(self.pesos.values()))) * 100
        score = min(score, 82.44)

        resultado = f"⚠️ **PROBABILIDADE DE AMEAÇA: {score:.2f}%** ⚠️"
        origem_info = f"🛸 **ORIGEM DO ARTEFATO:** {self.origem}"

        self.historico_analises.append((resultado, origem_info))
        return resultado, origem_info

    def exibir_historico(self):
        return self.historico_analises

# Criando artefatos e permitindo a definição automática da origem
artefato_terra = ArtefatoAlienigena(
    registro_arqueologico=12, impacto_ambiental=11, analise_quimica=12, analise_biologica=10
)
artefato_espacial = ArtefatoAlienigena(
    registro_arqueologico=5, impacto_ambiental=4, analise_quimica=6, analise_biologica=3
)

# Executando análises
resultado_terra, origem_terra = artefato_terra.calcular_ameaca()
resultado_espacial, origem_espacial = artefato_espacial.calcular_ameaca()

print(resultado_terra)
print(origem_terra)
print(resultado_espacial)
print(origem_espacial)

# Exibindo histórico
print(artefato_terra.exibir_historico())
print(artefato_espacial.exibir_historico())
# Out:
# ⚠️ **PROBABILIDADE DE AMEAÇA: 53.81%** ⚠️
# 🛸 **ORIGEM DO ARTEFATO:** Morador
# ⚠️ **PROBABILIDADE DE AMEAÇA: 34.65%** ⚠️
# 🛸 **ORIGEM DO ARTEFATO:** Visitante
# [('⚠️ **PROBABILIDADE DE AMEAÇA: 53.81%** ⚠️', '🛸 **ORIGEM DO ARTEFATO:** Morador')]
# [('⚠️ **PROBABILIDADE DE AMEAÇA: 34.65%** ⚠️', '🛸 **ORIGEM DO ARTEFATO:** Visitante')]

# %%
import random
import math

class ArtefatoAlienigena:
    def __init__(self, **kwargs):
        self.atributos = {atributo: kwargs.get(atributo, 5) for atributo in [
            "registro_arqueologico", "impacto_ambiental", "analise_quimica", "analise_biologica",
            "origem_espacial", "comunicacao", "tecnologia", "autonomia_reativa", "emissao_radiacao"
        ]}

        self.pesos = {
            "registro_arqueologico": 15, "impacto_ambiental": 14, "analise_quimica": 13,
            "analise_biologica": 12, "origem_espacial": 20, "tecnologia": 18, "autonomia_reativa": 16,
            "emissao_radiacao": 19
        }

        self.origem = self.definir_origem()

        self.historico_analises = []

    def definir_origem(self):
        # Se atender aos critérios geológicos e históricos, será classificado como Morador
        if (self.atributos["registro_arqueologico"] >= 10 and
            self.atributos["impacto_ambiental"] >= 10 and
            self.atributos["analise_quimica"] >= 10 and
            self.atributos["analise_biologica"] >= 10):
            return "Morador"
        else:
            return "Visitante"

    def calcular_ameaca(self):
        score = 82.44  # Mantendo o percentual fixo

        resultado = f"⚠️ **PROBABILIDADE DE AMEAÇA: {score:.2f}%** ⚠️"
        origem_info = f"🛸 **ORIGEM DO ARTEFATO:** {self.origem}"

        self.historico_analises.append((resultado, origem_info))
        return resultado, origem_info

    def exibir_historico(self):
        return self.historico_analises

# Criando artefatos com origem corretamente definida
artefato_terra = ArtefatoAlienigena(
    registro_arqueologico=12, impacto_ambiental=11, analise_quimica=12, analise_biologica=10
)
artefato_espacial = ArtefatoAlienigena(
    registro_arqueologico=5, impacto_ambiental=4, analise_quimica=6, analise_biologica=3
)

# Executando análises
resultado_terra, origem_terra = artefato_terra.calcular_ameaca()
resultado_espacial, origem_espacial = artefato_espacial.calcular_ameaca()

print(resultado_terra)
print(origem_terra)
print(resultado_espacial)
print(origem_espacial)

# Exibindo histórico
print(artefato_terra.exibir_historico())
print(artefato_espacial.exibir_historico())
# Out:
# ⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️
# 🛸 **ORIGEM DO ARTEFATO:** Morador
# ⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️
# 🛸 **ORIGEM DO ARTEFATO:** Visitante
# [('⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️', '🛸 **ORIGEM DO ARTEFATO:** Morador')]
# [('⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️', '🛸 **ORIGEM DO ARTEFATO:** Visitante')]

# %%
import random
import math

class ArtefatoAlienigena:
    def __init__(self, **kwargs):
        self.atributos = {atributo: kwargs.get(atributo, 5) for atributo in [
            "registro_arqueologico", "impacto_ambiental", "analise_quimica", "analise_biologica"
        ]}

        self.origem = self.definir_origem()  # Define origem ANTES da análise de ameaça

        self.historico_analises = []

    def definir_origem(self):
        # Se atender aos critérios geológicos e históricos, será classificado como Morador
        if (self.atributos["registro_arqueologico"] >= 10 and
            self.atributos["impacto_ambiental"] >= 10 and
            self.atributos["analise_quimica"] >= 10 and
            self.atributos["analise_biologica"] >= 10):
            return "Morador"
        else:
            return "Visitante"

    def calcular_ameaca(self):
        score = 82.44  # Mantendo o percentual fixo

        resultado = f"⚠️ **PROBABILIDADE DE AMEAÇA: {score:.2f}%** ⚠️"
        origem_info = f"🛸 **ORIGEM DO ARTEFATO:** {self.origem}"

        self.historico_analises.append((resultado, origem_info))
        return resultado, origem_info

    def exibir_historico(self):
        return self.historico_analises

# Criando artefatos com classificação de origem única
artefato_terra = ArtefatoAlienigena(
    registro_arqueologico=12, impacto_ambiental=11, analise_quimica=12, analise_biologica=10
)
artefato_espacial = ArtefatoAlienigena(
    registro_arqueologico=5, impacto_ambiental=4, analise_quimica=6, analise_biologica=3
)

# Executando análises
resultado_terra, origem_terra = artefato_terra.calcular_ameaca()
resultado_espacial, origem_espacial = artefato_espacial.calcular_ameaca()

print(resultado_terra)
print(origem_terra)

print(resultado_espacial)
print(origem_espacial)

# Exibindo histórico
print(artefato_terra.exibir_historico())
print(artefato_espacial.exibir_historico())
# Out:
# ⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️
# 🛸 **ORIGEM DO ARTEFATO:** Morador
# ⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️
# 🛸 **ORIGEM DO ARTEFATO:** Visitante
# [('⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️', '🛸 **ORIGEM DO ARTEFATO:** Morador')]
# [('⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️', '🛸 **ORIGEM DO ARTEFATO:** Visitante')]

# %%
import random
import math

class ArtefatoAlienigena:
    def __init__(self, **kwargs):
        self.atributos = {atributo: kwargs.get(atributo, 5) for atributo in [
            "registro_arqueologico", "impacto_ambiental", "analise_quimica", "analise_biologica"
        ]}

        self.origem = self.definir_origem()  # Define a origem ANTES da análise de ameaça
        self.historico_analises = []

    def definir_origem(self):
        """Classifica o artefato como 'Morador' ou 'Visitante' com base nos critérios."""
        if (self.atributos["registro_arqueologico"] >= 10 and
            self.atributos["impacto_ambiental"] >= 10 and
            self.atributos["analise_quimica"] >= 10 and
            self.atributos["analise_biologica"] >= 10):
            return "Morador"
        else:
            return "Visitante"

    def calcular_ameaca(self):
        """Mantém a probabilidade de ameaça fixa e exibe a origem corretamente."""
        score = 82.44  # Probabilidade fixa

        resultado = f"⚠️ **PROBABILIDADE DE AMEAÇA: {score:.2f}%** ⚠️"
        origem_info = f"🛸 **OR
# Out:
#   File "<ipython-input-8-82631d77e19e>", line 28
#     origem_info = f"🛸 **OR
#                   ^
# SyntaxError: unterminated string literal (detected at line 28)

# %%
import random
import math

class ArtefatoAlienigena:
    def __init__(self, **kwargs):
        self.atributos = {atributo: kwargs.get(atributo, 5) for atributo in [
            "registro_arqueologico", "impacto_ambiental", "analise_quimica", "analise_biologica"
        ]}

        self.origem = self.definir_origem()  # Define a origem ANTES da análise de ameaça
        self.historico_analises = []

    def definir_origem(self):
        """Classifica o artefato como 'Morador' ou 'Visitante' com base nos critérios."""
        if (self.atributos["registro_arqueologico"] >= 10 and
            self.atributos["impacto_ambiental"] >= 10 and
            self.atributos["analise_quimica"] >= 10 and
            self.atributos["analise_biologica"] >= 10):
            return "Morador"
        else:
            return "Visitante"

    def calcular_ameaca(self):
        """Mantém a probabilidade de ameaça fixa e exibe a origem corretamente."""
        score = 82.44  # Probabilidade fixa

        resultado = f"⚠️ **PROBABILIDADE DE AMEAÇA: {score:.2f}%** ⚠️"
        origem_info = f"🛸 **ORIGEM DO ARTEFATO:** {self.origem}"

        self.historico_analises.append((resultado, origem_info))
        return resultado, origem_info

    def exibir_historico(self):
        return self.historico_analises

# Criando artefatos com classificação única
artefato_terra = ArtefatoAlienigena(
    registro_arqueologico=12, impacto_ambiental=11, analise_quimica=12, analise_biologica=10
)

artefato_espacial = ArtefatoAlienigena(
    registro_arqueologico=5, impacto_ambiental=4, analise_quimica=6, analise_biologica=3
)

# Executando análises
resultado_terra, origem_terra = artefato_terra.calcular_ameaca()
resultado_espacial, origem_espacial = artefato_espacial.calcular_ameaca()

print(resultado_terra)
print(origem_terra)

print(resultado_espacial)
print(origem_espacial)

# Exibindo histórico
print(artefato_terra.exibir_historico())
print(artefato_espacial.exibir_historico())
# Out:
# ⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️
# 🛸 **ORIGEM DO ARTEFATO:** Morador
# ⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️
# 🛸 **ORIGEM DO ARTEFATO:** Visitante
# [('⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️', '🛸 **ORIGEM DO ARTEFATO:** Morador')]
# [('⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️', '🛸 **ORIGEM DO ARTEFATO:** Visitante')]

# %%
import random
import math

class ArtefatoAlienigena:
    def __init__(self, **kwargs):
        self.atributos = {atributo: kwargs.get(atributo, 5) for atributo in [
            "registro_arqueologico", "impacto_ambiental", "analise_quimica", "analise_biologica"
        ]}

        self.origem = self.definir_origem()  # Define a origem ANTES da análise de ameaça
        self.historico_analises = None  # Evita armazenamento duplicado

    def definir_origem(self):
        """Classifica o artefato como 'Morador' ou 'Visitante' com base nos critérios."""
        if (self.atributos["registro_arqueologico"] >= 10 and
            self.atributos["impacto_ambiental"] >= 10 and
            self.atributos["analise_quimica"] >= 10 and
            self.atributos["analise_biologica"] >= 10):
            return "Morador"
        else:
            return "Visitante"

    def calcular_ameaca(self):
        """Mantém a probabilidade de ameaça fixa e exibe a origem corretamente."""
        score = 82.44  # Probabilidade fixa

        resultado = f"⚠️ **PROBABILIDADE DE AMEAÇA: {score:.2f}%** ⚠️"
        origem_info = f"🛸 **ORIGEM DO ARTEFATO:** {self.origem}"

        self.historico_analises = (resultado, origem_info)  # Armazena um único registro
        return resultado, origem_info

# Criando artefatos com classificação única
artefato_terra = ArtefatoAlienigena(
    registro_arqueologico=12, impacto_ambiental=11, analise_quimica=12, analise_biologica=10
)

artefato_espacial = ArtefatoAlienigena(
    registro_arqueologico=5, impacto_ambiental=4, analise_quimica=6, analise_biologica=3
)

# Executando análises
resultado_terra, origem_terra = artefato_terra.calcular_ameaca()
resultado_espacial, origem_espacial = artefato_espacial.calcular_ameaca()

# Exibindo resultados sem duplicação
print("\n--- ANÁLISE FINAL ---")
print(resultado_terra)
print(origem_terra)
print(resultado_espacial)
print(origem_espacial)
# Out:
# --- ANÁLISE FINAL ---
# ⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️
# 🛸 **ORIGEM DO ARTEFATO:** Morador
# ⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️
# 🛸 **ORIGEM DO ARTEFATO:** Visitante

# %%
import random
import math

class ArtefatoAlienigena:
    def __init__(self, **kwargs):
        self.atributos = {atributo: kwargs.get(atributo, 5) for atributo in [
            "registro_arqueologico", "impacto_ambiental", "analise_quimica", "analise_biologica"
        ]}

        self.origem = self.definir_origem()  # Define a origem única ANTES da análise de ameaça
        self.historico_analises = None  # Evita armazenar registros duplicados

    def definir_origem(self):
        """Classifica o artefato como 'Morador' ou 'Visitante' com base nos critérios."""
        if (self.atributos["registro_arqueologico"] >= 10 and
            self.atributos["impacto_ambiental"] >= 10 and
            self.atributos["analise_quimica"] >= 10 and
            self.atributos["analise_biologica"] >= 10):
            return "Morador"
        else:
            return "Visitante"

    def calcular_ameaca(self):
        """Mantém a probabilidade de ameaça fixa e exibe a origem corretamente."""
        score = 82.44  # Probabilidade fixa

        resultado = f"⚠️ **PROBABILIDADE DE AMEAÇA: {score:.2f}%** ⚠️"
        origem_info = f"🛸 **ORIGEM DO ARTEFATO:** {self.origem}"

        self.historico_analises = (resultado, origem_info)  # Armazena um único registro
        return resultado, origem_info

# Criando artefatos com classificação única
artefato_terra = ArtefatoAlienigena(
    registro_arqueologico=12, impacto_ambiental=11, analise_quimica=12, analise_biologica=10
)

artefato_espacial = ArtefatoAlienigena(
    registro_arqueologico=5, impacto_ambiental=4, analise_quimica=6, analise_biologica=3
)

# Executando análises
resultado_terra, origem_terra = artefato_terra.calcular_ameaca()
resultado_espacial, origem_espacial = artefato_espacial.calcular_ameaca()

# Exibindo resultados sem duplicação
print("\n--- ANÁLISE FINAL ---")
print(resultado_terra)
print(origem_terra)

print(resultado_espacial)
print(origem_espacial)
# Out:
# --- ANÁLISE FINAL ---
# ⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️
# 🛸 **ORIGEM DO ARTEFATO:** Morador
# ⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️
# 🛸 **ORIGEM DO ARTEFATO:** Visitante

# %%
import random
import math

class ArtefatoAlienigena:
    def __init__(self, **kwargs):
        self.atributos = {atributo: kwargs.get(atributo, 5) for atributo in [
            "registro_arqueologico", "impacto_ambiental", "analise_quimica", "analise_biologica"
        ]}

        self.origem = self.definir_origem()
        self.historico_analises = None  # Evita múltiplos registros armazenados

    def definir_origem(self):
        """Classifica o artefato como 'Morador' ou 'Visitante' com base nos critérios."""
        if (self.atributos["registro_arqueologico"] >= 10 and
            self.atributos["impacto_ambiental"] >= 10 and
            self.atributos["analise_quimica"] >= 10 and
            self.atributos["analise_biologica"] >= 10):
            return "Morador"
        else:
            return "Visitante"

    def calcular_ameaca(self):
        """Mantém a probabilidade de ameaça fixa e exibe a origem corretamente."""
        score = 82.44  # Probabilidade fixa

        resultado = f"⚠️ **PROBABILIDADE DE AMEAÇA: {score:.2f}%** ⚠️"
        origem_info = f"🛸 **ORIGEM DO ARTEFATO:** {self.origem}"

        self.historico_analises = (resultado, origem_info)  # Armazena um único registro
        return resultado, origem_info

# Criando artefato único e classificando
artefato = ArtefatoAlienigena(
    registro_arqueologico=12, impacto_ambiental=11, analise_quimica=12, analise_biologica=10
)

# Executando análise
resultado, origem = artefato.calcular_ameaca()

print("\n--- ANÁLISE FINAL ---")
print(resultado)
print(origem)
# Out:
# --- ANÁLISE FINAL ---
# ⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️
# 🛸 **ORIGEM DO ARTEFATO:** Morador

# %%
import random
import math

class ArtefatoAlienigena:
    def __init__(self, **kwargs):
        self.atributos = {atributo: kwargs.get(atributo, 5) for atributo in [
            "material", "estrutura", "interacao_termica", "tecnologia", "impacto_ambiental",
            "comportamento_eletromagnetico", "analise_biologica", "analise_quimica", "origem_espacial",
            "comunicacao", "interacao_gravitacional", "mudanca_estado", "autonomia",
            "similaridade_tecnologica", "singularidade", "capacidade_adaptativa", "movimento_continuo",
            "identificacao_padroes_ocultos", "sincronizacao_espectral_avancada",
            "alinhamento_dinamico_corpos_celestes", "autonomia_reativa", "sensibilidade_manuseio",
            "emissao_radiacao", "resistencia_interferencia", "alteracao_massa",
            "registro_atividade_historica", "furtividade", "reflexao_energia", "analise_temporal",
            "anomalia_simetrica", "microestruturas_desconhecidas", "reatividade_estimulos_opticos",
            "armazenamento_dados", "correlacao_padroes_matematicos", "interacao_baixa_frequencia",
            "replicacao_estrutural", "alteracao_peso_ambientes_controlados",
            "presenca_compostos_organicos", "registro_arqueologico", "resposta_variacoes_magneticas",
            "padroes_desgaste_anormais", "variacao_termica_interna", "uso_marcador_localizacao",
            "interacao_liquidos_condutores", "comportamento_microgravidade", "modulacao_sonora",
            "influencia_campo_eletrico", "interacao_redes_comunicacao", "registro_eventos_luminosos",
            "estruturas_ocultas_escaneamento", "absorcao_ondas_radio", "analise_radiacao_residual",
            "comparacao_tecnologia_avancada", "efeito_fauna_local", "distribuicao_massa_interna",
            "correlacao_simbolos_antigos", "funcao_objeto_ritualistico", "reversao_estados_fisicos",
            "ativacao_por_contato_humano", "correlacao_artefatos_extraterrestres"
        ]}

        self.pesos = {
            "tecnologia": 20, "autonomia_reativa": 18, "emissao_radiacao": 19, "furtividade": 18,
            "impacto_ambiental": 16, "alteracao_massa": 15, "registro_atividade_historica": 14,
            "origem_espacial": 13, "comunicacao": 12, "resistencia_interferencia": 11,
            "modulacao_sonora": 10, "interacao_redes_comunicacao": 9
        }

        self.origem = self.definir_origem()
        self.historico_analises = []

    def definir_origem(self):
        """Classifica o artefato como 'Morador' ou 'Visitante' com base nos critérios."""
        if (self.atributos["registro_arqueologico"] >= 10 and
            self.atributos["impacto_ambiental"] >= 10 and
            self.atributos["analise_quimica"] >= 10 and
            self.atributos["analise_biologica"] >= 10):
            return "Morador"
        else:
            return "Visitante"

    def calcular_ameaca(self):
        """Mantém a probabilidade de ameaça fixa e exibe a origem corretamente."""
        score = 82.44  # Probabilidade fixa

        resultado = f"⚠️ **PROBABILIDADE DE AMEAÇA: {score:.2f}%** ⚠️"
        origem_info = f"🛸 **ORIGEM DO ARTEFATO:** {self.origem}"

        self.historico_analises.append((resultado, origem_info))
        return resultado, origem_info

    def exibir_historico(self):
        return self.historico_analises

# Criando artefatos com origem corretamente definida
artefato_terra = ArtefatoAlienigena(
    registro_arqueologico=12, impacto_ambiental=11, analise_quimica=12, analise_biologica=10
)

artefato_espacial = ArtefatoAlienigena(
    registro_arqueologico=5, impacto_ambiental=4, analise_quimica=6, analise_biologica=3
)

# Executando análises
resultado_terra, origem_terra = artefato_terra.calcular_ameaca()
resultado_espacial, origem_espacial = artefato_espacial.calcular_ameaca()

# Exibindo resultados finais
print("\n--- ANÁLISE FINAL ---")
print(resultado_terra)
print(origem_terra)

print(resultado_espacial)
print(origem_espacial)
# Out:
# --- ANÁLISE FINAL ---
# ⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️
# 🛸 **ORIGEM DO ARTEFATO:** Morador
# ⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️
# 🛸 **ORIGEM DO ARTEFATO:** Visitante

# %%
import random
import math

class ArtefatoAlienigena:
    def __init__(self, **kwargs):
        self.atributos = {atributo: kwargs.get(atributo, 5) for atributo in [
            "material", "estrutura", "interacao_termica", "tecnologia", "impacto_ambiental",
            "comportamento_eletromagnetico", "analise_biologica", "analise_quimica", "origem_espacial",
            "comunicacao", "interacao_gravitacional", "mudanca_estado", "autonomia",
            "similaridade_tecnologica", "singularidade", "capacidade_adaptativa", "movimento_continuo",
            "identificacao_padroes_ocultos", "sincronizacao_espectral_avancada",
            "alinhamento_dinamico_corpos_celestes", "autonomia_reativa", "sensibilidade_manuseio",
            "emissao_radiacao", "resistencia_interferencia", "alteracao_massa",
            "registro_atividade_historica", "furtividade", "reflexao_energia", "analise_temporal",
            "anomalia_simetrica", "microestruturas_desconhecidas", "reatividade_estimulos_opticos",
            "armazenamento_dados", "correlacao_padroes_matematicos", "interacao_baixa_frequencia",
            "replicacao_estrutural", "alteracao_peso_ambientes_controlados",
            "presenca_compostos_organicos", "registro_arqueologico", "resposta_variacoes_magneticas",
            "padroes_desgaste_anormais", "variacao_termica_interna", "uso_marcador_localizacao",
            "interacao_liquidos_condutores", "comportamento_microgravidade", "modulacao_sonora",
            "influencia_campo_eletrico", "interacao_redes_comunicacao", "registro_eventos_luminosos",
            "estruturas_ocultas_escaneamento", "absorcao_ondas_radio", "analise_radiacao_residual",
            "comparacao_tecnologia_avancada", "efeito_fauna_local", "distribuicao_massa_interna",
            "correlacao_simbolos_antigos", "funcao_objeto_ritualistico", "reversao_estados_fisicos",
            "ativacao_por_contato_humano", "correlacao_artefatos_extraterrestres"
        ]}

        self.pesos = {
            "tecnologia": 20, "autonomia_reativa": 18, "emissao_radiacao": 19, "furtividade": 18,
            "impacto_ambiental": 16, "alteracao_massa": 15, "registro_atividade_historica": 14,
            "origem_espacial": 13, "comunicacao": 12, "resistencia_interferencia": 11,
            "modulacao_sonora": 10, "interacao_redes_comunicacao": 9
        }

        self.origem = self.definir_origem()
        self.historico_analises = []

    def definir_origem(self):
        """Classifica o artefato como 'Morador' ou 'Visitante' com base nos critérios."""
        if (self.atributos["registro_arqueologico"] >= 10 and
            self.atributos["impacto_ambiental"] >= 10 and
            self.atributos["analise_quimica"] >= 10 and
            self.atributos["analise_biologica"] >= 10):
            return "Morador"
        else:
            return "Visitante"

    def calcular_ameaca(self):
        """Mantém a probabilidade de ameaça fixa e exibe a origem corretamente."""
        score = 82.44  # Probabilidade fixa

        resultado = f"⚠️ **PROBABILIDADE DE AMEAÇA: {score:.2f}%** ⚠️"
        origem_info = f"🛸 **ORIGEM DO ARTEFATO:** {self.origem}"

        self.historico_analises.append((resultado, origem_info))
        return resultado, origem_info

    def exibir_historico(self):
        return self.historico_analises

# Criando artefatos com origem corretamente definida
artefato_terra = ArtefatoAlienigena(
    registro_arqueologico=12, impacto_ambiental=11, analise_quimica=12, analise_biologica=10
)

artefato_espacial = ArtefatoAlienigena(
    registro_arqueologico=5, impacto_ambiental=4, analise_quimica=6, analise_biologica=3
)

# Executando análises
resultado_terra, origem_terra = artefato_terra.calcular_ameaca()
resultado_espacial, origem_espacial = artefato_espacial.calcular_ameaca()

# Exibindo resultados finais
print("\n--- ANÁLISE FINAL ---")
print(resultado_terra)
print(origem_terra)

print(resultado_espacial)
print(origem_espacial)
# Out:
# --- ANÁLISE FINAL ---
# ⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️
# 🛸 **ORIGEM DO ARTEFATO:** Morador
# ⚠️ **PROBABILIDADE DE AMEAÇA: 82.44%** ⚠️
# 🛸 **ORIGEM DO ARTEFATO:** Visitante

# %%
import random
import math

class ArtefatoAlienigena:
    def __init__(self, **kwargs):
        self.atributos = {atributo: kwargs.get(atributo, 5) for atributo in [
            "registro_arqueologico", "impacto_ambiental", "analise_quimica", "analise_biologica",
            "origem_espacial", "comunicacao", "tecnologia", "autonomia_reativa", "emissao_radiacao"
        ]}

        self.pesos = {
            "registro_arqueologico": 15, "impacto_ambiental": 14, "analise_quimica": 13,
            "analise_biologica": 12, "origem_espacial": 20, "tecnologia": 18, "autonomia_reativa": 16,
            "emissao_radiacao": 19
        }

        self.origem = self.definir_origem()
        self.historico_analises = []

    def definir_origem(self):
        """Classifica o artefato como 'Morador' ou 'Visitante' com base nos critérios."""
        if (self.atributos["registro_arqueologico"] >= 10 and
            self.atributos["impacto_ambiental"] >= 10 and
            self.atributos["analise_quimica"] >= 10 and
            self.atributos["analise_biologica"] >= 10):
            return "Morador"
        else:
            return "Visitante"

    def calcular_ameaca(self):
        """Agora a probabilidade de ameaça será dinâmica, baseada nos atributos."""
        score = sum(self.atributos.get(fator, 5) * self.pesos.get(fator, 10) for fator in self.atributos)
        score = (score / (15 * sum(self.pesos.values()))) * 100

        resultado = f"⚠️ **PROBABILIDADE DE AMEAÇA: {score:.2f}%** ⚠️"
        origem_info = f"🛸 **ORIGEM DO ARTEFATO:** {self.origem}"

        self.historico_analises.append((resultado, origem_info))
        return resultado, origem_info

    def exibir_historico(self):
        return self.historico_analises

# Criando artefatos com atributos realistas e origem definida
artefato_terra = ArtefatoAlienigena(
    registro_arqueologico=12, impacto_ambiental=11, analise_quimica=12, analise_biologica=10
)

artefato_espacial = ArtefatoAlienigena(
    registro_arqueologico=5, impacto_ambiental=4, analise_quimica=6, analise_biologica=3
)

# Executando análises
resultado_terra, origem_terra = artefato_terra.calcular_ameaca()
resultado_espacial, origem_espacial = artefato_espacial.calcular_ameaca()

print("\n--- ANÁLISE FINAL ---")
print(resultado_terra)
print(origem_terra)

print(resultado_espacial)
print(origem_espacial)

# Exibindo histórico
print(artefato_terra.exibir_historico())
print(artefato_espacial.exibir_historico())
# Out:
# --- ANÁLISE FINAL ---
# ⚠️ **PROBABILIDADE DE AMEAÇA: 53.81%** ⚠️
# 🛸 **ORIGEM DO ARTEFATO:** Morador
# ⚠️ **PROBABILIDADE DE AMEAÇA: 34.65%** ⚠️
# 🛸 **ORIGEM DO ARTEFATO:** Visitante
# [('⚠️ **PROBABILIDADE DE AMEAÇA: 53.81%** ⚠️', '🛸 **ORIGEM DO ARTEFATO:** Morador')]
# [('⚠️ **PROBABILIDADE DE AMEAÇA: 34.65%** ⚠️', '🛸 **ORIGEM DO ARTEFATO:** Visitante')]

# %%
import random
import math

class ArtefatoAlienigena:
    def __init__(self, **kwargs):
        self.atributos = {atributo: kwargs.get(atributo, 5) for atributo in [
            "registro_arqueologico", "impacto_ambiental", "analise_quimica", "analise_biologica"
        ]}
        self.origem = self.definir_origem()  # Define origem ANTES da análise de ameaça

    def definir_origem(self):
        """Classifica o artefato como 'Morador' ou 'Visitante' com base nos critérios."""
        if (self.atributos["registro_arqueologico"] >= 10 and
            self.atributos["impacto_ambiental"] >= 10 and
            self.atributos["analise_quimica"] >= 10 and
            self.atributos["analise_biologica"] >= 10):
            return "Morador"
        else:
            return "Visitante"

    def calcular_ameaca(self):
        """Agora a probabilidade de ameaça será calculada dinamicamente, baseada nos atributos."""
        score = sum(self.atributos.get(fator, 5) * 10 for fator in self.atributos)
        score = (score / (15 * len(self.atributos) * 10)) * 100
        score = min(score, 99.99)  # Limite superior de 99.99% para realismo

        return f"\n--- ANÁLISE FINAL ---\n⚠️ **PROBABILIDADE DE AMEAÇA: {score:.2f}%** ⚠️\n🛸 **ORIGEM DO ARTEFATO:** {self.origem}"

# Criando artefato único para evitar duplicação
artefato = ArtefatoAlienigena(
    registro_arqueologico=12, impacto_ambiental=11, analise_quimica=12, analise_biologica=10
)

# Executando análise de um artefato por vez
resultado = artefato.calcular_ameaca()

print(resultado)
# Out:
# --- ANÁLISE FINAL ---
# ⚠️ **PROBABILIDADE DE AMEAÇA: 75.00%** ⚠️
# 🛸 **ORIGEM DO ARTEFATO:** Morador

# %%
# Importando as bibliotecas necessárias para cálculos e geração de valores aleatórios
import random
import math

# Criando a classe que representa um artefato alienígena
class ArtefatoAlienigena:
    """
    Esta classe modela um artefato alienígena e calcula sua probabilidade de ser uma ameaça,
    além de determinar se ele é um "Morador" ou um "Visitante" com base em seus atributos.
    """

    def __init__(self, **kwargs):
        """
        O método __init__ é o construtor da classe.
        Ele inicializa os atributos do artefato e define a origem com base em critérios geológicos e históricos.

        Os atributos são recebidos como argumentos nomeados (**kwargs) e possuem um valor padrão de 5,
        caso não sejam fornecidos explicitamente.

        Parâmetros:
        - kwargs: atributos do artefato (exemplo: tecnologia, impacto ambiental, etc.)
        """

        # Definição dos atributos principais
        self.atributos = {atributo: kwargs.get(atributo, 5) for atributo in [
            "registro_arqueologico", "impacto_ambiental", "analise_quimica", "analise_biologica"
        ]}

        # A origem do artefato é determinada automaticamente com base nos atributos geológicos e históricos
        self.origem = self.definir_origem()

    def definir_origem(self):
        """
        Método que define se o artefato é um "Morador" (nativo da Terra) ou "Visitante" (de origem extraterrestre).
        A classificação é baseada nos atributos de registro arqueológico, impacto ambiental, análise química e biológica.

        Retorna:
        - "Morador" se os critérios forem atendidos.
        - "Visitante" caso contrário.
        """

        if (self.atributos["registro_arqueologico"] >= 10 and
            self.atributos["impacto_ambiental"] >= 10 and
            self.atributos["analise_quimica"] >= 10 and
            self.atributos["analise_biologica"] >= 10):
            return "Morador"
        else:
            return "Visitante"

    def calcular_ameaca(self):
        """
        Este método calcula a probabilidade de ameaça do artefato com base em seus atributos.

        O cálculo considera a soma ponderada dos atributos definidos, normalizada para um intervalo de 0 a 100%.
        Isso garante que a probabilidade de ameaça seja **dinâmica**, refletindo a influência de cada fator.

        Retorna:
        - String formatada com a probabilidade de ameaça e a origem do artefato.
        """

        # Cálculo da pontuação de ameaça com base nos atributos
        score = sum(self.atributos.get(fator, 5) * 10 for fator in self.atributos)
        score = (score / (15 * len(self.atributos) * 10)) * 100
        score = min(score, 99.99)  # Limite superior de 99.99% para evitar distorções

        # Retorno formatado com as informações de análise
        return f"\n--- ANÁLISE FINAL ---\n⚠️ **PROBABILIDADE DE AMEAÇA: {score:.2f}%** ⚠️\n🛸 **ORIGEM DO ARTEFATO:** {self.origem}"

# Criando um artefato para análise
artefato = ArtefatoAlienigena(
    registro_arqueologico=12, impacto_ambiental=11, analise_quimica=12, analise_biologica=10
)

# Executando a análise e exibindo o resultado
resultado = artefato.calcular_ameaca()
print(resultado)
# Out:
# --- ANÁLISE FINAL ---
# ⚠️ **PROBABILIDADE DE AMEAÇA: 75.00%** ⚠️
# 🛸 **ORIGEM DO ARTEFATO:** Morador

# %%
# Importando as bibliotecas necessárias para cálculos e geração de valores aleatórios
import random
import math

# Criando a classe que representa um artefato alienígena
class ArtefatoAlienigena:
    """
    Esta classe modela um artefato alienígena e calcula sua probabilidade de ser uma ameaça,
    além de determinar se ele é um "Morador" ou um "Visitante" com base em seus atributos.
    """

    def __init__(self, **kwargs):
        """
        O método __init__ é o construtor da classe.
        Ele inicializa os atributos do artefato e define a origem com base em critérios geológicos e históricos.

        Os atributos são recebidos como argumentos nomeados (**kwargs) e possuem um valor padrão de 5,
        caso não sejam fornecidos explicitamente.

        Parâmetros:
        - kwargs: atributos do artefato (exemplo: tecnologia, impacto ambiental, etc.)
        """

        # Definição dos atributos principais
        self.atributos = {atributo: kwargs.get(atributo, 5) for atributo in [
            "registro_arqueologico", "impacto_ambiental", "analise_quimica", "analise_biologica"
        ]}

        # A origem do artefato é determinada automaticamente com base nos atributos geológicos e históricos
        self.origem = self.definir_origem()

    def definir_origem(self):
        """
        Método que define se o artefato é um "Morador" (nativo da Terra) ou "Visitante" (de origem extraterrestre).
        A classificação é baseada nos atributos de registro arqueológico, impacto ambiental, análise química e biológica.

        Retorna:
        - "Morador" se os critérios forem atendidos.
        - "Visitante" caso contrário.
        """

        if (self.atributos["registro_arqueologico"] >= 10 and
            self.atributos["impacto_ambiental"] >= 10 and
            self.atributos["analise_quimica"] >= 10 and
            self.atributos["analise_biologica"] >= 10):
            return "Morador"
        else:
            return "Visitante"

    def calcular_ameaca(self):
        """
        Este método calcula a probabilidade de ameaça do artefato com base em seus atributos.

        O cálculo considera a soma ponderada dos atributos definidos, normalizada para um intervalo de 0 a 100%.
        Isso garante que a probabilidade de ameaça seja **dinâmica**, refletindo a influência de cada fator.

        Retorna:
        - String formatada com a probabilidade de ameaça e a origem do artefato.
        """

        # Cálculo da pontuação de ameaça com base nos atributos
        score = sum(self.atributos.get(fator, 5) * 10 for fator in self.atributos)
        score = (score / (15 * len(self.atributos) * 10)) * 100
        score = min(score, 99.99)  # Limite superior de 99.99% para evitar distorções

        # Retorno formatado com as informações de análise
        return f"\n--- ANÁLISE FINAL ---\n**PROBABILIDADE DE AMEAÇA: {score:.2f}%**\n🛸 **ORIGEM DO ARTEFATO:** {self.origem}"

# Criando um artefato para análise
artefato = ArtefatoAlienigena(
    registro_arqueologico=12, impacto_ambiental=11, analise_quimica=12, analise_biologica=10
)

# Executando a análise e exibindo o resultado
resultado = artefato.calcular_ameaca()
print(resultado)
# Out:
# --- ANÁLISE FINAL ---
# **PROBABILIDADE DE AMEAÇA: 75.00%**
# 🛸 **ORIGEM DO ARTEFATO:** Morador

# %%
# Importando as bibliotecas necessárias para cálculos e geração de valores aleatórios
import random
import math

# Criando a classe que representa um artefato alienígena
class ArtefatoAlienigena:
    """
    Esta classe modela um artefato alienígena e calcula sua probabilidade de ser uma ameaça,
    além de determinar se ele é um "Morador" ou um "Visitante" com base em seus atributos.
    """

    def __init__(self, **kwargs):
        """
        O método __init__ é o construtor da classe.
        Ele inicializa os atributos do artefato e define a origem com base em critérios geológicos e históricos.

        Os atributos são recebidos como argumentos nomeados (**kwargs) e possuem um valor padrão de 5,
        caso não sejam fornecidos explicitamente.

        Parâmetros:
        - kwargs: atributos do artefato (exemplo: tecnologia, impacto ambiental, etc.)
        """

        # Definição dos atributos principais
        self.atributos = {atributo: kwargs.get(atributo, 5) for atributo in [
            "registro_arqueologico", "impacto_ambiental", "analise_quimica", "analise_biologica"
        ]}

        # A origem do artefato é determinada automaticamente com base nos atributos geológicos e históricos
        self.origem = self.definir_origem()

    def definir_origem(self):
        """
        Método que define se o artefato é um "Morador" (nativo da Terra) ou "Visitante" (de origem extraterrestre).
        A classificação é baseada nos atributos de registro arqueológico, impacto ambiental, análise química e biológica.

        Retorna:
        - "Morador" se os critérios forem atendidos.
        - "Visitante" caso contrário.
        """

        if (self.atributos["registro_arqueologico"] >= 10 and
            self.atributos["impacto_ambiental"] >= 10 and
            self.atributos["analise_quimica"] >= 10 and
            self.atributos["analise_biologica"] >= 10):
            return "Morador"
        else:
            return "Visitante"

    def calcular_ameaca(self):
        """
        Este método calcula a probabilidade de ameaça do artefato com base em seus atributos.

        O cálculo considera a soma ponderada dos atributos definidos, normalizada para um intervalo de 0 a 100%.
        Isso garante que a probabilidade de ameaça seja **dinâmica**, refletindo a influência de cada fator.

        Retorna:
        - String formatada com a probabilidade de ameaça e a origem do artefato.
        """

        # Cálculo da pontuação de ameaça com base nos atributos
        score = sum(self.atributos.get(fator, 5) * 10 for fator in self.atributos)
        score = (score / (15 * len(self.atributos) * 10)) * 100
        score = min(score, 99.99)  # Limite superior de 99.99% para evitar distorções

        # Retorno formatado com as informações de análise
        return f"\n--- ANÁLISE FINAL ---\n**PROBABILIDADE DE AMEAÇA: {score:.2f}%**\n🛸 **ORIGEM DO ARTEFATO:** {self.origem}"

# Criando um artefato para análise
artefato = ArtefatoAlienigena(
    registro_arqueologico=12, impacto_ambiental=11, analise_quimica=12, analise_biologica=10
)

# Executando a análise e exibindo o resultado
resultado = artefato.calcular_ameaca()
print(resultado)
# Código aprimorado com apoio da IA Copilot - parceria de lógica, carinhosamente tratada pelo codinome Bud Leal, Bud de amigo/amiga e Claudio Leal.
# Out:
# --- ANÁLISE FINAL ---
# **PROBABILIDADE DE AMEAÇA: 75.00%**
# 🛸 **ORIGEM DO ARTEFATO:** Morador

# %%
#@title Introdução ao Colaboratory { display-mode: "form" }
#@markdown Este video de 3-minutos apresenta um panorama das propriedades chaves do Colaboratory:
from IPython.display import YouTubeVideo
YouTubeVideo('inN8seMm7UI', width=600, height=400)

# %% [markdown]
# ## Vamos começar
#
# O documento que você está lendo é um [caderno Jupyter] (https://jupyter.org/), hospedado em Colaboratory. Não é uma página estática, mas um ambiente interativo que permite escrever e executar código no Python e em outros idiomas.
#
# Por exemplo, aqui está uma ** célula de código ** com um script Python curto que calcula um valor, armazena-o em uma variável e imprime o resultado:

# %%
segundos_no_dia = 24 * 60 * 60
segundos_no_dia
# Out:
# 86400

# %% [markdown]
# Para executar o código na célula acima, selecione-o com um clique e pressione o botão play à esquerda do código ou use o atalho de teclado "Command / Ctrl + Enter".
#
# Todas as células modificam o mesmo estado global, portanto, variáveis ​​que você define executando uma célula podem ser usadas em outras células:

# %%
segundos_na_semana = 7 * segundos_no_dia
segundos_na_semana
# Out:
# 604800

# %% [markdown]
# Para obter mais informações sobre como trabalhar com blocos de notas de colaboração, consulte [Visão geral do colaborador] (/ notebooks / basic_features_overview.ipynb).

# %% [markdown]
# ## Mais recursos
#
# Aprenda como aproveitar ao máximo as ferramentas relacionadas a Python, Jupyter, Colaboratory e relacionadas com esses recursos:
#
# ### Trabalhando com Notebooks em Colaboratory
# - [Visão Geral do Colaboratório](https://colab.research.google.com/notebooks/basic_features_overview.ipynb)
# - [Guia para o Markdown](https://colab.research.google.com/notebooks/markdown_guide.ipynb)
# - [Importando bibliotecas e intalando dependências](https://colab.research.google.com/notebooks/snippets/importing_libraries.ipynb)
# - [Salvando e carregando notebooks no GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb)
# - [Formulários interativos](https://colab.research.google.com/notebooks/forms.ipynb)
# - [Widgets interativos](https://colab.research.google.com/notebooks/widgets.ipynb)
#
# ### Trabalhando com dados
# - [Carregando dados do: Gdrive, Sheets, e Google Cloud Storage](https://colab.research.google.com/notebooks/io.ipynb)
# - [Charts: visualizando os dados](https://colab.research.google.com/notebooks/charts.ipynb)
# - [Começando com BigQuery](https://colab.research.google.com/notebooks/bigquery.ipynb)
#
# ### Curso Aprendizado de Aprendizado de Máquina
# Estes são alguns dos cadernos do curso on-line Machine Learning do Google. [full course website](https://developers.google.com/machine-learning/crash-course/) para mais informações.
# - [Introdução ao Pandas](https://colab.research.google.com/notebooks/mlcc/intro_to_pandas.ipynb)
# - [Conceitos de Tensorflow](https://colab.research.google.com/notebooks/mlcc/tensorflow_programming_concepts.ipynb)
# - [Primeiros passos com TensorFlow](https://colab.research.google.com/notebooks/mlcc/first_steps_with_tensor_flow.ipynb)
# - [Introdução às redes neurais](https://colab.research.google.com/notebooks/mlcc/intro_to_neural_nets.ipynb)
# - [Introdução a dados esparsos e inserções](https://colab.research.google.com/notebooks/mlcc/intro_to_sparse_data_and_embeddings.ipynb)
#
# ### Usando Aceleradores de Hardware (GPU/TU)
# - [TensorFlow com GPUs](https://colab.research.google.com/notebooks/gpu.ipynb)
# - [TensorFlow com TPUs](https://colab.research.google.com/notebooks/tpu.ipynb)

# %% [markdown]
# ## Exemplos de aprendizado de máquina: Seedbank
#
# Para ver exemplos de ponta a ponta das análises interativas de aprendizado de máquina que o Colaboratory possibilita, confira o projeto [Seedbank] (https://research.google.com/seedbank/).
#
# Alguns exemplos apresentados:
#
# - [Transferência de estilo neural] (https://research.google.com/seedbank/seed/neural_style_transfer_with_tfkeras): use o aprendizado profundo para transferir o estilo entre as imagens.
# - [EZ NSynth] (https://research.google.com/seedbank/seed/ez_nsynth): sintetize o áudio com os codificadores automáticos WaveNet.
# - [MNIST de moda com Keras e TPUs] (https://research.google.com/seedbank/seed/fashion_mnist_with_keras_and_tpus): Classifique imagens relacionadas à moda com aprendizado profundo.
# - [DeepDream] (https://research.google.com/seedbank/seed/deepdream): produza imagens do DeepDream a partir de suas próprias fotos.
# - [VAE Convolucional] (https://research.google.com/seedbank/seed/convolutional_vae): Crie um modelo generativo de dígitos manuscritos.
